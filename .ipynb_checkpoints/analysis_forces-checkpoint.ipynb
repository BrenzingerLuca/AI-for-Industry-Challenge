# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("aic_solution_policy/data/try_01.csv")
df.head()
# Out:
#                       wall_time_iso   wall_time_s  wrench_stamp_s  \
# 0  2026-04-15T11:11:39.624829+00:00  1.776251e+09          17.842
# 1  2026-04-15T11:11:39.806054+00:00  1.776251e+09          17.942
# 2  2026-04-15T11:11:39.972074+00:00  1.776251e+09          18.042
# 3  2026-04-15T11:11:40.141779+00:00  1.776252e+09          18.144
# 4  2026-04-15T11:11:40.302740+00:00  1.776252e+09          18.246
#
#    abs_force_x  abs_force_y  abs_force_z  abs_torque_x  abs_torque_y  \
# 0     0.029490     0.655878    20.682840      0.054280     -0.093435
# 1    -0.210619     0.475879    20.490664      0.045972     -0.121471
# 2    -0.023159     0.498961    20.960053      0.103998     -0.058733
# 3     4.959048    -0.692353    15.706296      1.032352      0.487851
# 4     2.469879     0.360883    18.554740     -0.025065     -0.004913
#
#    abs_torque_z  delta_force_x  ...  delta_force_z  delta_torque_x  \
# 0      0.057836       0.000000  ...       0.000000        0.000000
# ...
